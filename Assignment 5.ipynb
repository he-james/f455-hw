# %% [markdown]
# # Financial Data Analytics
#
#
# ## Assignment 5

# %% [markdown]
# ## Question 1
#
# Write a function that returns the name of a company for a given ticker symbol.
#
# You should scrape the data from Yahoo! Finance. [Here's an example page](https://finance.yahoo.com/quote/WMT/profile) using Walmart. Start by making your function modify the URL so it works for other ticker symbols. Then, look at the HTML source to find the pattern that you must search for to extract the company name.
#
# I've started the function for you here.

# %%
def get_name(ticker):
    import requests, re
    
    # put the URL here
    # https://finance.yahoo.com/quote/WMT/profile
    url = "http://finance.yahoo.com/quote/" + ticker + "/profile"
    
    # download
    req= requests.get(url)
    html = req.text
    
    try:
        # use a regular expression to find the name
        # (Your code goes here)
        regex = r"<title>(.+?) \(" + ticker + "\)"
        name = re.findall(regex, html)
        return name[0]
        
    except:
        # if the regular expression fails, do nothing
        return

# %% [markdown]
# Test your function using these tickers: `AMZN`, `WMT`, `MMM`. Be sure it works as expected.

# %%
get_name("AMZN")
get_name("WMT")
get_name("MMM")
# Out:
# '3M Company'

# %% [markdown]
# ## Question 2
# Write a function that uses the same web page of data to find the address of the company's headquarters.
#
# For example, your function should work as follows:
#
#     In  []: get_address('TSLA')
#     Out []: '3500 Deer Creek Road, Palo Alto, CA, 94304'
#
# Be sure to test your function with some other stock tickers.
#
# Hints:
# You can use the basic structure for the code presented above.
# You'll probably want to capture different parts of the address (street address, city, state, zip) separately and then join them together into a string before returning a value.

# %%
def get_address(ticker):
    import re, requests
    
    url = "https://finance.yahoo.com/quote/" + ticker + "/profile"
        
    req= requests.get(url)
    html = req.text
    
    try:
        # use a regular expression to find the name
        # (Your code goes here)
        regex = r"react-text: 9 -->(.*?)<!.*?text: 11 -->(.*)<!"
        name = re.findall(regex, html)
        return name
    except:
        # if the regular expression fails, do nothing
        return

# %%
print(get_address("AMZN"))
print(get_address("WMT"))
print(get_address("MMM"))
# Out:
# ('410 Terry Avenue North', 'Seattle, WA 98109-5210<!-- /react-text --><br data-reactid="12"/><!-- react-text: 13 -->United States<!-- /react-text --><br data-reactid="14"/><a href="tel:206-266-1000" data-reactid="15">206-266-1000</a><br data-reactid="16"/><a href="http://www.amazon.com" rel="noopener noreferrer" target="_blank" title="" data-reactid="17">http://www.amazon.com</a></p><p class="D(ib) Va(t)" data-reactid="18"><span data-reactid="19">Sector</span><!-- react-text: 20 -->:\xa0<!-- /react-text --><span class="Fw(600)" data-reactid="21">Consumer Cyclical</span><br data-reactid="22"/><span data-reactid="23">Industry</span><!-- react-text: 24 -->:\xa0<!-- /react-text --><span class="Fw(600)" data-reactid="25">Internet Retail</span><br data-reactid="26"/><span data-reactid="27">Full Time Employees</span><!-- react-text: 28 -->:\xa0<!-- /react-text --><span class="Fw(600)" data-reactid="29"><span data-reactid="30">798,000</span></span></p></div></div></div><div class="" data-reactid="31"><div id="defaultLREC-sizer" class="darla-container D-n D(n) lrec-ldrb-ad darla-nonlrec34-ad darla-nonlrec34ldrb-ad darla-lrec-ad" data-reactid="32"><!-- react-text: 33 --><!-- /react-text --><div id="defaultLREC-wrapper" class="" data-reactid="34"><div id="defaultdestLREC" style=""></div></div></div></div><section class="Bxz(bb) quote-subsection undefined" data-reactid="35"><h3 class="Fz(m) Fw(br) Mb(15px) Mt(0)" data-reactid="36"><span data-reactid="37">Key Executives</span></h3><table class="W(100%)" data-reactid="38"><thead data-reactid="39"><tr class="C($tertiaryColor) Fz(xs) BdB Bdc($seperatorColor)" data-reactid="40"><th class="Ta(start) Py(6px) Fw(n)" data-reactid="41"><span data-reactid="42">Name</span></th><th class="Ta(start) Py(6px) Fw(n)" data-reactid="43"><span data-reactid="44">Title</span></th><th class="Ta(end) Py(6px) Fw(n)" data-reactid="45"><span data-reactid="46">Pay</span></th><th class="Ta(end) Py(6px) Fw(n)" data-reactid="47"><span data-reactid="48">Exercised</span></th><th class="Ta(end) Py(6px) Fw(n)" data-reactid="49"><span data-reactid="50">Year Born</span></th></tr></thead><tbody data-reactid="51"><tr class="C($primaryColor) BdB Bdc($seperatorColor) H(36px)" data-reactid="52"><td class="Ta(start)" data-reactid="53"><span class="" data-reactid="54"><!-- react-text: 55 -->Mr. Jeffrey P. Bezos<!-- /react-text --></span></td><td class="Ta(start) W(45%)" data-reactid="56"><span class="" data-reactid="57"><!-- react-text: 58 -->Founder, Chairman, Pres &amp; CEO<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="59"><span class="" data-reactid="60"><!-- react-text: 61 -->1.68M<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="62"><span class="" data-reactid="63"><span data-reactid="64">N/A</span></span></td><td class="Ta(end)" data-reactid="65"><span class="" data-reactid="66"><!-- react-text: 67 -->1964<!-- /react-text --></span></td></tr><tr class="C($primaryColor) BdB Bdc($seperatorColor) H(36px)" data-reactid="68"><td class="Ta(start)" data-reactid="69"><span class="" data-reactid="70"><!-- react-text: 71 -->Mr. Brian T. Olsavsky<!-- /react-text --></span></td><td class="Ta(start) W(45%)" data-reactid="72"><span class="" data-reactid="73"><!-- react-text: 74 -->Sr. VP &amp; CFO<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="75"><span class="" data-reactid="76"><!-- react-text: 77 -->163.2k<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="78"><span class="" data-reactid="79"><span data-reactid="80">N/A</span></span></td><td class="Ta(end)" data-reactid="81"><span class="" data-reactid="82"><!-- react-text: 83 -->1964<!-- /react-text --></span></td></tr><tr class="C($primaryColor) BdB Bdc($seperatorColor) H(36px)" data-reactid="84"><td class="Ta(start)" data-reactid="85"><span class="" data-reactid="86"><!-- react-text: 87 -->Mr. Jeffrey A. Wilke<!-- /react-text --></span></td><td class="Ta(start) W(45%)" data-reactid="88"><span class="" data-reactid="89 ...
# ('702 SW 8th Street', 'Bentonville, AR 72716<!-- /react-text --><br data-reactid="12"/><!-- react-text: 13 -->United States<!-- /react-text --><br data-reactid="14"/><a href="tel:479-273-4000" data-reactid="15">479-273-4000</a><br data-reactid="16"/><a href="http://www.stock.walmart.com" rel="noopener noreferrer" target="_blank" title="" data-reactid="17">http://www.stock.walmart.com</a></p><p class="D(ib) Va(t)" data-reactid="18"><span data-reactid="19">Sector</span><!-- react-text: 20 -->:\xa0<!-- /react-text --><span class="Fw(600)" data-reactid="21">Consumer Defensive</span><br data-reactid="22"/><span data-reactid="23">Industry</span><!-- react-text: 24 -->:\xa0<!-- /react-text --><span class="Fw(600)" data-reactid="25">Discount Stores</span><br data-reactid="26"/><span data-reactid="27">Full Time Employees</span><!-- react-text: 28 -->:\xa0<!-- /react-text --><span class="Fw(600)" data-reactid="29"><span data-reactid="30">2,200,000</span></span></p></div></div></div><div class="" data-reactid="31"><div id="defaultLREC-sizer" class="darla-container D-n D(n) lrec-ldrb-ad darla-nonlrec34-ad darla-nonlrec34ldrb-ad darla-lrec-ad" data-reactid="32"><!-- react-text: 33 --><!-- /react-text --><div id="defaultLREC-wrapper" class="" data-reactid="34"><div id="defaultdestLREC" style=""></div></div></div></div><section class="Bxz(bb) quote-subsection undefined" data-reactid="35"><h3 class="Fz(m) Fw(br) Mb(15px) Mt(0)" data-reactid="36"><span data-reactid="37">Key Executives</span></h3><table class="W(100%)" data-reactid="38"><thead data-reactid="39"><tr class="C($tertiaryColor) Fz(xs) BdB Bdc($seperatorColor)" data-reactid="40"><th class="Ta(start) Py(6px) Fw(n)" data-reactid="41"><span data-reactid="42">Name</span></th><th class="Ta(start) Py(6px) Fw(n)" data-reactid="43"><span data-reactid="44">Title</span></th><th class="Ta(end) Py(6px) Fw(n)" data-reactid="45"><span data-reactid="46">Pay</span></th><th class="Ta(end) Py(6px) Fw(n)" data-reactid="47"><span data-reactid="48">Exercised</span></th><th class="Ta(end) Py(6px) Fw(n)" data-reactid="49"><span data-reactid="50">Year Born</span></th></tr></thead><tbody data-reactid="51"><tr class="C($primaryColor) BdB Bdc($seperatorColor) H(36px)" data-reactid="52"><td class="Ta(start)" data-reactid="53"><span class="" data-reactid="54"><!-- react-text: 55 -->Mr. C. Douglas McMillon<!-- /react-text --></span></td><td class="Ta(start) W(45%)" data-reactid="56"><span class="" data-reactid="57"><!-- react-text: 58 -->Pres, CEO &amp; Director<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="59"><span class="" data-reactid="60"><!-- react-text: 61 -->6.93M<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="62"><span class="" data-reactid="63"><span data-reactid="64">N/A</span></span></td><td class="Ta(end)" data-reactid="65"><span class="" data-reactid="66"><!-- react-text: 67 -->1966<!-- /react-text --></span></td></tr><tr class="C($primaryColor) BdB Bdc($seperatorColor) H(36px)" data-reactid="68"><td class="Ta(start)" data-reactid="69"><span class="" data-reactid="70"><!-- react-text: 71 -->Mr. M. Brett Biggs<!-- /react-text --></span></td><td class="Ta(start) W(45%)" data-reactid="72"><span class="" data-reactid="73"><!-- react-text: 74 -->Exec. VP &amp; CFO<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="75"><span class="" data-reactid="76"><!-- react-text: 77 -->3.44M<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="78"><span class="" data-reactid="79"><span data-reactid="80">N/A</span></span></td><td class="Ta(end)" data-reactid="81"><span class="" data-reactid="82"><!-- react-text: 83 -->1968<!-- /react-text --></span></td></tr><tr class="C($primaryColor) BdB Bdc($seperatorColor) H(36px)" data-reactid="84"><td class="Ta(start)" data-reactid="85"><span class="" data-reactid="86"><!-- react-text: 87 -->Ms. Judith  McKenna<!-- /react-text --></span></td><td class="Ta(start) W(45%)" data-reactid="88"><span class="" data-reactid=" ...
# ('3M Center', 'St. Paul, MN 55144<!-- /react-text --><br data-reactid="12"/><!-- react-text: 13 -->United States<!-- /react-text --><br data-reactid="14"/><a href="tel:651-733-1110" data-reactid="15">651-733-1110</a><br data-reactid="16"/><a href="http://www.3m.com" rel="noopener noreferrer" target="_blank" title="" data-reactid="17">http://www.3m.com</a></p><p class="D(ib) Va(t)" data-reactid="18"><span data-reactid="19">Sector</span><!-- react-text: 20 -->:\xa0<!-- /react-text --><span class="Fw(600)" data-reactid="21">Industrials</span><br data-reactid="22"/><span data-reactid="23">Industry</span><!-- react-text: 24 -->:\xa0<!-- /react-text --><span class="Fw(600)" data-reactid="25">Specialty Industrial Machinery</span><br data-reactid="26"/><span data-reactid="27">Full Time Employees</span><!-- react-text: 28 -->:\xa0<!-- /react-text --><span class="Fw(600)" data-reactid="29"><span data-reactid="30">96,163</span></span></p></div></div></div><div class="" data-reactid="31"><div id="defaultLREC-sizer" class="darla-container D-n D(n) lrec-ldrb-ad darla-nonlrec34-ad darla-nonlrec34ldrb-ad darla-lrec-ad" data-reactid="32"><!-- react-text: 33 --><!-- /react-text --><div id="defaultLREC-wrapper" class="" data-reactid="34"><div id="defaultdestLREC" style=""></div></div></div></div><section class="Bxz(bb) quote-subsection undefined" data-reactid="35"><h3 class="Fz(m) Fw(br) Mb(15px) Mt(0)" data-reactid="36"><span data-reactid="37">Key Executives</span></h3><table class="W(100%)" data-reactid="38"><thead data-reactid="39"><tr class="C($tertiaryColor) Fz(xs) BdB Bdc($seperatorColor)" data-reactid="40"><th class="Ta(start) Py(6px) Fw(n)" data-reactid="41"><span data-reactid="42">Name</span></th><th class="Ta(start) Py(6px) Fw(n)" data-reactid="43"><span data-reactid="44">Title</span></th><th class="Ta(end) Py(6px) Fw(n)" data-reactid="45"><span data-reactid="46">Pay</span></th><th class="Ta(end) Py(6px) Fw(n)" data-reactid="47"><span data-reactid="48">Exercised</span></th><th class="Ta(end) Py(6px) Fw(n)" data-reactid="49"><span data-reactid="50">Year Born</span></th></tr></thead><tbody data-reactid="51"><tr class="C($primaryColor) BdB Bdc($seperatorColor) H(36px)" data-reactid="52"><td class="Ta(start)" data-reactid="53"><span class="" data-reactid="54"><!-- react-text: 55 -->Mr. Michael F. Roman<!-- /react-text --></span></td><td class="Ta(start) W(45%)" data-reactid="56"><span class="" data-reactid="57"><!-- react-text: 58 -->CEO, Pres &amp; Chairman<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="59"><span class="" data-reactid="60"><!-- react-text: 61 -->2.62M<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="62"><span class="" data-reactid="63"><!-- react-text: 64 -->1.12M<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="65"><span class="" data-reactid="66"><!-- react-text: 67 -->1960<!-- /react-text --></span></td></tr><tr class="C($primaryColor) BdB Bdc($seperatorColor) H(36px)" data-reactid="68"><td class="Ta(start)" data-reactid="69"><span class="" data-reactid="70"><!-- react-text: 71 -->Mr. Nicholas C. Gangestad<!-- /react-text --></span></td><td class="Ta(start) W(45%)" data-reactid="72"><span class="" data-reactid="73"><!-- react-text: 74 -->Sr. VP &amp; CFO<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="75"><span class="" data-reactid="76"><!-- react-text: 77 -->1.68M<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="78"><span class="" data-reactid="79"><!-- react-text: 80 -->287.52k<!-- /react-text --></span></td><td class="Ta(end)" data-reactid="81"><span class="" data-reactid="82"><!-- react-text: 83 -->1965<!-- /react-text --></span></td></tr><tr class="C($primaryColor) BdB Bdc($seperatorColor) H(36px)" data-reactid="84"><td class="Ta(start)" data-reactid="85"><span class="" data-reactid="86"><!-- react-text: 87 -->Ms. Julie L. Bushman<!-- /react-text --></span></td><td class="Ta(start) W(45%)" data-reactid="88"><span class="" data-reac ...

# %% [markdown]
# ## Question 3
#
# Now I want you to write a *geolocating* function that takes a ticker symbol and returns the latitude and longitude of the firm's headquarters. To do this, we will use Mapquest's API (<b>A</b>pplication <b>P</b>rogramming <b>I</b>nterface), which is a web-based system for providing raw data rather than HTML pages.
#
# Before accessing the API you need to create an account which generates an API Key. The account is free and allows you to make a limited number of queries. To sign up, go [here](https://developer.mapquest.com/user/register) and choose Sign Up. You are assigned a key when you register. It will look something like this:
#
# <pre>zAWt8Aye6YvhIupZMzctaAfkSkEnaccN</pre>
#
# Once you have created your key, you can query the API using a URL like this:
#
# http://www.mapquestapi.com/geocoding/v1/address?key=API_KEY&location=1309+E+10th+Street%2C+Bloomington%2C+IN%2C+47401
#
# (This link won't work until you replace `API_KEY` with your personal key.)
#
# Notice there is a special formatting to deal with spaces and other punctuation. An easy way to request a web site like this is as follows:

# %%
import requests

url = 'http://www.mapquestapi.com/geocoding/v1/address'
params = {'key': '8XJAIbKUhAGSqZlAAbrnPfHsCMagzdpM', 'location': '1309 E 10th Street, Bloomington, IN, 47401'}
requests.get(url, params=params).text
# Out:
# '{"info":{"statuscode":0,"copyright":{"text":"\\u00A9 2020 MapQuest, Inc.","imageUrl":"http://api.mqcdn.com/res/mqlogo.gif","imageAltText":"\\u00A9 2020 MapQuest, Inc."},"messages":[]},"options":{"maxResults":-1,"thumbMaps":true,"ignoreLatLngInput":false},"results":[{"providedLocation":{"location":"1309 E 10th Street, Bloomington, IN, 47401"},"locations":[{"street":"1309 E 10th St","adminArea6":"","adminArea6Type":"Neighborhood","adminArea5":"Bloomington","adminArea5Type":"City","adminArea4":"Monroe","adminArea4Type":"County","adminArea3":"IN","adminArea3Type":"State","adminArea1":"US","adminArea1Type":"Country","postalCode":"47405-1701","geocodeQualityCode":"L1AAB","geocodeQuality":"ADDRESS","dragPoint":false,"sideOfStreet":"L","linkId":"rnr3440297|i21503866","unknownInput":"","type":"s","latLng":{"lat":39.171598,"lng":-86.517943},"displayLatLng":{"lat":39.171798,"lng":-86.517941},"mapUrl":"http://www.mapquestapi.com/staticmap/v5/map?key=8XJAIbKUhAGSqZlAAbrnPfHsCMagzdpM&type=map&size=225,160&locations=39.171598,-86.517943|marker-sm-50318A-1&scalebar=true&zoom=15&rand=607610478"}]}]}'

# %% [markdown]
# The response from the server is data from the database stored in JSON format. But you can ignore that it's JSON and just use a regular expression to find the pattern you're looking for.
#
# As an example, your function should return a tuple *exactly* like this:
#
#     In  [2]: geolocate('TSLA')
#     Out [2]: (37.394738, -122.149112, '3500 Deer Creek Road, Palo Alto, CA, 94304')
#
# That is, it returns a tuple with the latitude, longitude, and address.
#
# The function you write for this question should start by calling the function you wrote in Q2 to get the address. You can then use this with the API to get the location

# %%
geolocate('TSLA')

# %% [markdown]
# ## Question 4
#
# Now let's say we want to calculate the distance between two corporate headquarters.
#
# Given two pairs of latitude and longitude, $(\varphi_1, \lambda_1)$ and $(\varphi_2, \lambda_2)$, we can calculate the distance between them using the [Haversine formula](https://en.wikipedia.org/wiki/Haversine_formula#The_haversine_formula):
#
# $${\displaystyle d=2r\arcsin \left({\sqrt {\operatorname {hav} (\varphi _{2}-\varphi _{1})+\cos(\varphi _{1})\cos(\varphi _{2})\operatorname {hav} (\lambda _{2}-\lambda _{1})}}\right)}$$
#
# where $d$ is the distance, $\operatorname{hav}$ is the Haversine function, $$\operatorname {hav} (\theta )=\sin ^{2}\left({\frac {\theta }{2}}\right),$$ and $r$ is the radius of the earth ([3958.7613 miles](https://en.wikipedia.org/wiki/Earth_radius#Mean_radius)). Note that this formula requires that the latitude and longitude are given in *radians*, not the degrees that Mapquest gives.
#
# Use the template below to write a function that takes two ticker symbols and returns the distance between the headquarters of the two firms. Note that the python function for $\arcsin$ is `asin`.

# %%
def haversine(theta):
    '''Haversine function'''
    from math import sin
    return sin(theta/2)**2

def firm_dist(ticker1, ticker2):
    '''Returns the distance in miles between two firm HQs'''
    
    from math import radians, cos, sin, asin, sqrt
    
    # get lat/lng of two tickers

    
    # change degrees to radians
    # hint: use the map function

    
    # calculate distance

# %%
# test your function

d = firm_dist('GOOG', 'FB')

print(f'Google and Facebook are {d:.1f} miles apart')
